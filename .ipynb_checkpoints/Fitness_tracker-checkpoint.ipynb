# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
fitness_df = pd.read_csv("random_fitness_dataset.csv")
fitness_df.head(10)
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
# 5          6  2025-07-25 13:00:54    U005   39  Female               HIIT
# 6          7  2025-05-21 08:47:54    U030   61   Other            Walking
# 7          8  2025-06-28 14:29:54    U014   46  Female               Yoga
# 8          9  2025-08-02 19:57:54    U036   63    Male           Swimming
# 9         10  2025-08-31 09:54:54    U019   27   Other           Swimming
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
# 5            50              471             163  23432          7.4
# 6            88              238              78  14851          6.8
# 7            39              133             179  15351          4.5
# 8            10              500              82  13072          4.7
# 9           100              210             165  22439          6.3
#
#    weight_kg
# 0       84.3
# 1       79.6
# 2       88.3
# 3       69.0
# 4       61.6
# 5       98.7
# 6       61.8
# 7       46.0
# 8       72.6
# 9       73.7

# %%
fitness_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   record_id        200 non-null    int64
#  1   timestamp        200 non-null    object
#  2   user_id          200 non-null    object
#  3   age              200 non-null    int64
#  4   gender           200 non-null    object
#  5   activity_type    200 non-null    object
#  6   duration_min     200 non-null    int64
#  7   calories_burned  200 non-null    int64
#  8   heart_rate_avg   200 non-null    int64
#  9   steps            200 non-null    int64
#  10  sleep_hours      200 non-null    float64
#  11  weight_kg        200 non-null    float64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 18.9+ KB

# %%
fitness_df.describe()
# Out:
#         record_id         age  duration_min  calories_burned  heart_rate_avg  \
# count  200.000000  200.000000    200.000000       200.000000      200.000000
# mean   100.500000   44.380000     64.025000       295.765000      120.935000
# std     57.879185   15.417982     34.693987       120.563834       34.100366
# min      1.000000   16.000000      5.000000        50.000000       60.000000
# 25%     50.750000   33.000000     33.000000       220.000000       89.750000
# 50%    100.500000   43.000000     68.000000       311.500000      121.000000
# 75%    150.250000   58.000000     95.000000       378.000000      150.250000
# max    200.000000   69.000000    119.000000       585.000000      179.000000
#
#              steps  sleep_hours   weight_kg
# count    200.00000   200.000000  200.000000
# mean   14020.82000     6.313000   70.152000
# std     6428.05981     1.911518   14.129562
# min      370.00000     3.000000   35.300000
# 25%     9585.00000     4.775000   61.450000
# 50%    14857.00000     6.500000   70.600000
# 75%    19007.75000     7.900000   80.100000
# max    24984.00000     9.500000  105.200000

# %%
fitness_df.isna().values.any() # check if there are any null values
# Out:
# np.False_

# %%
fitness_df.isnull().sum() # count the number of null values
# Out:
# record_id          0
# timestamp          0
# user_id            0
# age                0
# gender             0
# activity_type      0
# duration_min       0
# calories_burned    0
# heart_rate_avg     0
# steps              0
# sleep_hours        0
# weight_kg          0
# dtype: int64

# %%
"""
Data Transformation
   Date Transformation into:
   Date, Month, day, hour
"""
fitness_df['time_stamp'] = pd.to_datetime(fitness_df['timestamp'])
fitness_df['time_stamp'].head()
# Out:
# 0   2025-07-22 09:22:54
# 1   2025-05-28 13:53:54
# 2   2025-08-07 01:36:54
# 3   2025-07-17 01:56:54
# 4   2025-08-11 03:22:54
# Name: time_stamp, dtype: datetime64[ns]

# %%
# Get the date
fitness_df['date'] = fitness_df['time_stamp'].dt.date
fitness_df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg          time_stamp        date
# 0       84.3 2025-07-22 09:22:54  2025-07-22
# 1       79.6 2025-05-28 13:53:54  2025-05-28
# 2       88.3 2025-08-07 01:36:54  2025-08-07
# 3       69.0 2025-07-17 01:56:54  2025-07-17
# 4       61.6 2025-08-11 03:22:54  2025-08-11

# %%
# Extracting the month name
fitness_df['month']  = fitness_df['time_stamp'].dt.month_name()
fitness_df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg          time_stamp        date   month
# 0       84.3 2025-07-22 09:22:54  2025-07-22    July
# 1       79.6 2025-05-28 13:53:54  2025-05-28     May
# 2       88.3 2025-08-07 01:36:54  2025-08-07  August
# 3       69.0 2025-07-17 01:56:54  2025-07-17    July
# 4       61.6 2025-08-11 03:22:54  2025-08-11  August

# %%
#Extracting day
fitness_df['day'] = fitness_df['time_stamp'].dt.day_name()
fitness_df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg          time_stamp        date   month        day
# 0       84.3 2025-07-22 09:22:54  2025-07-22    July    Tuesday
# 1       79.6 2025-05-28 13:53:54  2025-05-28     May  Wednesday
# 2       88.3 2025-08-07 01:36:54  2025-08-07  August   Thursday
# 3       69.0 2025-07-17 01:56:54  2025-07-17    July   Thursday
# 4       61.6 2025-08-11 03:22:54  2025-08-11  August     Monday

# %%
# Extract Hour of the day
fitness_df['hour'] = fitness_df['time_stamp'].dt.hour
fitness_df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg          time_stamp        date   month        day  hour
# 0       84.3 2025-07-22 09:22:54  2025-07-22    July    Tuesday     9
# 1       79.6 2025-05-28 13:53:54  2025-05-28     May  Wednesday    13
# 2       88.3 2025-08-07 01:36:54  2025-08-07  August   Thursday     1
# 3       69.0 2025-07-17 01:56:54  2025-07-17    July   Thursday     1
# 4       61.6 2025-08-11 03:22:54  2025-08-11  August     Monday     3

# %%
fitness_df.describe()
# Out:
#         record_id         age  duration_min  calories_burned  heart_rate_avg  \
# count  200.000000  200.000000    200.000000       200.000000      200.000000
# mean   100.500000   44.380000     64.025000       295.765000      120.935000
# min      1.000000   16.000000      5.000000        50.000000       60.000000
# 25%     50.750000   33.000000     33.000000       220.000000       89.750000
# 50%    100.500000   43.000000     68.000000       311.500000      121.000000
# 75%    150.250000   58.000000     95.000000       378.000000      150.250000
# max    200.000000   69.000000    119.000000       585.000000      179.000000
# std     57.879185   15.417982     34.693987       120.563834       34.100366
#
#              steps  sleep_hours   weight_kg                  time_stamp  \
# count    200.00000   200.000000  200.000000                         200
# mean   14020.82000     6.313000   70.152000  2025-07-23 09:56:07.200000
# min      370.00000     3.000000   35.300000         2025-04-24 14:20:54
# 25%     9585.00000     4.775000   61.450000         2025-06-07 09:19:54
# 50%    14857.00000     6.500000   70.600000         2025-07-24 19:38:24
# 75%    19007.75000     7.900000   80.100000         2025-09-02 16:14:09
# max    24984.00000     9.500000  105.200000         2025-10-16 12:55:54
# std     6428.05981     1.911518   14.129562                         NaN
#
#             hour
# count  200.00000
# mean    11.08500
# min      0.00000
# 25%      5.00000
# 50%     11.00000
# 75%     17.00000
# max     23.00000
# std      7.02671

# %%
# understanding how each activity burn thr callories
fitness_df.groupby('activity_type')['calories_burned'].mean().sort_values(ascending = False)
# Out:
# activity_type
# HIIT                 320.629630
# Yoga                 318.523810
# Walking              304.033333
# Running              302.833333
# Swimming             286.925926
# Strength Training    267.444444
# Cycling              250.478261
# Name: calories_burned, dtype: float64

# %%
# Which day of the week has more people training
fitness_df.groupby('day')['user_id'].count().sort_values(ascending = False)
# Out:
# day
# Thursday     34
# Friday       32
# Saturday     30
# Tuesday      28
# Wednesday    28
# Monday       26
# Sunday       22
# Name: user_id, dtype: int64

# %%
# Which month did people train the most
fitness_df.groupby('month')['user_id'].count().sort_values(ascending = False)
# Out:
# month
# August       43
# June         37
# July         29
# May          28
# September    27
# October      25
# April        11
# Name: user_id, dtype: int64

# %%
def seasons(x):
    if x == 'December' or x == 'January' or x == 'February':
        return 'Winter'
    elif x == 'September' or x == 'October' or x== 'November':
        return 'Autumn'
    elif x == 'June' or x == 'July' or x == 'August':  
        return 'Summer'
    elif x == 'March' or x == 'April' or x == 'May':
        return 'Spring'

        
fitness_df['season'] = fitness_df['month'].apply(seasons)

# %%
fitness_df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg          time_stamp        date   month        day  hour  season
# 0       84.3 2025-07-22 09:22:54  2025-07-22    July    Tuesday     9  Summer
# 1       79.6 2025-05-28 13:53:54  2025-05-28     May  Wednesday    13  Spring
# 2       88.3 2025-08-07 01:36:54  2025-08-07  August   Thursday     1  Summer
# 3       69.0 2025-07-17 01:56:54  2025-07-17    July   Thursday     1  Summer
# 4       61.6 2025-08-11 03:22:54  2025-08-11  August     Monday     3  Summer

# %%
fitness_df.groupby('season')['user_id'].count().sort_values(ascending = 0)
# Out:
# season
# Summer    109
# Autumn     52
# Spring     39
# Name: user_id, dtype: int64

# %%
def week_time(day):
    if day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']:
        return 'weekday'
    elif day in ['Saturday', 'Sunday']:
        return 'weekend'
    else:
        return 'NULL'

fitness_df['week_time'] = fitness_df['day'].apply(week_time)

# %%
fitness_df.head()
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
#
#    duration_min  calories_burned  heart_rate_avg  steps  sleep_hours  \
# 0             7              322             175   3591          7.0
# 1            83              265             113  22312          5.7
# 2           118              508              98   5418          6.6
# 3            75              270             150  19809          7.9
# 4            76              308             141  12562          5.0
#
#    weight_kg          time_stamp        date   month        day  hour  season  \
# 0       84.3 2025-07-22 09:22:54  2025-07-22    July    Tuesday     9  Summer
# 1       79.6 2025-05-28 13:53:54  2025-05-28     May  Wednesday    13  Spring
# 2       88.3 2025-08-07 01:36:54  2025-08-07  August   Thursday     1  Summer
# 3       69.0 2025-07-17 01:56:54  2025-07-17    July   Thursday     1  Summer
# 4       61.6 2025-08-11 03:22:54  2025-08-11  August     Monday     3  Summer
#
#   week_time
# 0   weekday
# 1   weekday
# 2   weekday
# 3   weekday
# 4   weekday

# %%
# Generating a simple summary
fitness_df.groupby(['week_time']).agg({
'steps' : ['count','mean'],
'steps' : ['max', 'mean', 'min'],
'calories_burned' : ['max', 'mean', 'min']
})
# Out:
#            steps                     calories_burned
#              max          mean   min             max        mean min
# week_time
# weekday    24984  13494.689189   370             585  304.081081  50
# weekend    24095  15518.269231  3126             504  272.096154  50

# %%
# Generating a simple summary
fitness_df.groupby(['season']).agg({
'steps' : ['count','mean'],
'steps' : ['max', 'mean', 'min'],
'calories_burned' : ['max', 'mean', 'min']
})
# Out:
#         steps                     calories_burned
#           max          mean   min             max        mean min
# season
# Autumn  24409  13714.038462   633             563  305.538462  50
# Spring  24789  14270.076923  1354             443  258.179487  50
# Summer  24984  14077.990826   370             585  304.550459  50

# %%
# Generating a simple summary
fitness_df.groupby('month').agg({
'steps' : ['count','mean'],
'steps' : ['max', 'mean', 'min'],
'calories_burned' : ['max', 'mean', 'min']
}).reset_index()
# Out:
#        month  steps                     calories_burned
#                 max          mean   min             max        mean  min
# 0      April  23062  12322.727273  1354             443  220.636364   50
# 1     August  24819  14526.930233  1803             552  297.534884   50
# 2       July  24435  14312.137931  1267             567  299.827586  108
# 3       June  24984  13372.729730   370             585  316.405405   50
# 4        May  24789  15035.107143  4079             435  272.928571   50
# 5    October  24409  12946.600000   633             563  325.880000   50
# 6  September  23482  14424.629630  1872             476  286.703704   50

# %%
# Generating a simple summary
fitness_df.groupby(['day']).agg({
'steps' : ['count','mean'],
'steps' : ['max', 'mean', 'min'],
'calories_burned' : ['max', 'mean', 'min']
}).reset_index()
# Out:
#          day  steps                      calories_burned
#                 max          mean    min             max        mean  min
# 0     Friday  24968  13519.093750    370             502  321.812500   50
# 1     Monday  24984  14419.153846    960             545  318.346154   50
# 2   Saturday  24095  14515.566667   3126             504  271.400000   50
# 3     Sunday  23838  16885.590909  10048             468  273.045455  124
# 4   Thursday  24789  11397.382353    633             585  322.264706   50
# 5    Tuesday  24819  14785.107143   1872             552  258.250000   50
# 6  Wednesday  22336  13864.678571   3411             567  294.321429   50

# %%
# Generating a simple summary
fitness_df.groupby(['gender']).agg({
'steps' : ['count','mean'],
'steps' : ['max', 'mean', 'min'],
'calories_burned' : ['max', 'mean', 'min']
}).reset_index()
# Out:
#    gender  steps                    calories_burned
#              max          mean  min             max        mean min
# 0  Female  24789  13724.144928  721             563  296.623188  50
# 1    Male  24968  13594.507937  370             545  298.095238  50
# 2   Other  24984  14716.823529  633             585  292.735294  50

# %%
# Generating a simple summary
fitness_df.groupby(['activity_type']).agg({
'steps' : ['count','mean'],
'steps' : ['max', 'mean', 'min'],
'calories_burned' : ['max', 'mean', 'min']
}).sort_values(by = 'activity_type', ascending = 0)
# Out:
#                    steps                     calories_burned
#                      max          mean   min             max        mean min
# activity_type
# Yoga               24789  13197.642857   370             563  318.523810  50
# Walking            24984  14111.966667   633             530  304.033333  50
# Swimming           24968  15064.333333  1354             500  286.925926  50
# Strength Training  24819  14543.333333  2971             585  267.444444  50
# Running            23909  13122.083333   721             545  302.833333  50
# HIIT               23432  13943.555556   960             567  320.629630  50
# Cycling            24095  14595.260870  3591             508  250.478261  50

# %%
fitness_df['year'] = fitness_df['time_stamp'].dt.year

# %%
fitness_df['born'] = fitness_df['year'] - fitness_df['age']

# %%
def generation(year):
    if year >= 1946 and year < 1964:
        return 'Baby Boomers'
    elif year >= 1965 and year < 1980:
        return 'Generation X'
    elif year >= 1981 and year <  1996:
        return 'Millennials (Gen Y)'
    elif year >= 1997 and year < 2012:
        return 'Generation Z'
    elif year >= 2012:
        return 'Generation Alpha'
    else:
        return 'NULL'

fitness_df['Generation'] = fitness_df['born'].apply(generation)

# %%
fitness_df.head(10)
# Out:
#    record_id            timestamp user_id  age  gender      activity_type  \
# 0          1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1          2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2          3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3          4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4          5  2025-08-11 03:22:54    U042   42   Other               Yoga
# 5          6  2025-07-25 13:00:54    U005   39  Female               HIIT
# 6          7  2025-05-21 08:47:54    U030   61   Other            Walking
# 7          8  2025-06-28 14:29:54    U014   46  Female               Yoga
# 8          9  2025-08-02 19:57:54    U036   63    Male           Swimming
# 9         10  2025-08-31 09:54:54    U019   27   Other           Swimming
#
#    duration_min  calories_burned  heart_rate_avg  steps  ...  \
# 0             7              322             175   3591  ...
# 1            83              265             113  22312  ...
# 2           118              508              98   5418  ...
# 3            75              270             150  19809  ...
# 4            76              308             141  12562  ...
# 5            50              471             163  23432  ...
# 6            88              238              78  14851  ...
# 7            39              133             179  15351  ...
# 8            10              500              82  13072  ...
# 9           100              210             165  22439  ...
#
#            time_stamp        date   month        day hour  season  week_time  \
# 0 2025-07-22 09:22:54  2025-07-22    July    Tuesday    9  Summer    weekday
# 1 2025-05-28 13:53:54  2025-05-28     May  Wednesday   13  Spring    weekday
# 2 2025-08-07 01:36:54  2025-08-07  August   Thursday    1  Summer    weekday
# 3 2025-07-17 01:56:54  2025-07-17    July   Thursday    1  Summer    weekday
# 4 2025-08-11 03:22:54  2025-08-11  August     Monday    3  Summer    weekday
# 5 2025-07-25 13:00:54  2025-07-25    July     Friday   13  Summer    weekday
# 6 2025-05-21 08:47:54  2025-05-21     May  Wednesday    8  Spring    weekday
# 7 2025-06-28 14:29:54  2025-06-28    June   Saturday   14  Summer    weekend
# 8 2025-08-02 19:57:54  2025-08-02  August   Saturday   19  Summer    weekend
# 9 2025-08-31 09:54:54  2025-08-31  August     Sunday    9  Summer    weekend
#
#    year  born           Generation
# 0  2025  1958         Baby Boomers
# 1  2025  2009         Generation Z
# 2  2025  1963         Baby Boomers
# 3  2025  1969         Generation X
# 4  2025  1983  Millennials (Gen Y)
# 5  2025  1986  Millennials (Gen Y)
# 6  2025  1964                 NULL
# 7  2025  1979         Generation X
# 8  2025  1962         Baby Boomers
# 9  2025  1998         Generation Z
#
# [10 rows x 22 columns]

# %%
fitness_df
# Out:
#      record_id            timestamp user_id  age  gender      activity_type  \
# 0            1  2025-07-22 09:22:54    U026   67    Male            Cycling
# 1            2  2025-05-28 13:53:54    U039   16  Female  Strength Training
# 2            3  2025-08-07 01:36:54    U046   62  Female            Cycling
# 3            4  2025-07-17 01:56:54    U048   56  Female           Swimming
# 4            5  2025-08-11 03:22:54    U042   42   Other               Yoga
# ..         ...                  ...     ...  ...     ...                ...
# 195        196  2025-05-28 13:00:54    U011   62  Female               Yoga
# 196        197  2025-10-10 22:31:54    U045   17    Male               Yoga
# 197        198  2025-06-12 04:53:54    U021   41   Other  Strength Training
# 198        199  2025-10-11 21:37:54    U009   66   Other               Yoga
# 199        200  2025-07-11 04:47:54    U027   44   Other            Running
#
#      duration_min  calories_burned  heart_rate_avg  steps  ...  \
# 0               7              322             175   3591  ...
# 1              83              265             113  22312  ...
# 2             118              508              98   5418  ...
# 3              75              270             150  19809  ...
# 4              76              308             141  12562  ...
# ..            ...              ...             ...    ...  ...
# 195            84              435             130  18532  ...
# 196            65              408              73   8355  ...
# 197            99              585              89  22822  ...
# 198            74              230              72  16001  ...
# 199            68              241              80   7358  ...
#
#              time_stamp        date    month        day hour  season  \
# 0   2025-07-22 09:22:54  2025-07-22     July    Tuesday    9  Summer
# 1   2025-05-28 13:53:54  2025-05-28      May  Wednesday   13  Spring
# 2   2025-08-07 01:36:54  2025-08-07   August   Thursday    1  Summer
# 3   2025-07-17 01:56:54  2025-07-17     July   Thursday    1  Summer
# 4   2025-08-11 03:22:54  2025-08-11   August     Monday    3  Summer
# ..                  ...         ...      ...        ...  ...     ...
# 195 2025-05-28 13:00:54  2025-05-28      May  Wednesday   13  Spring
# 196 2025-10-10 22:31:54  2025-10-10  October     Friday   22  Autumn
# 197 2025-06-12 04:53:54  2025-06-12     June   Thursday    4  Summer
# 198 2025-10-11 21:37:54  2025-10-11  October   Saturday   21  Autumn
# 199 2025-07-11 04:47:54  2025-07-11     July     Friday    4  Summer
#
#      week_time  year  born           Generation
# 0      weekday  2025  1958         Baby Boomers
# 1      weekday  2025  2009         Generation Z
# 2      weekday  2025  1963         Baby Boomers
# 3      weekday  2025  1969         Generation X
# 4      weekday  2025  1983  Millennials (Gen Y)
# ..         ...   ...   ...                  ...
# 195    weekday  2025  1963         Baby Boomers
# 196    weekday  2025  2008         Generation Z
# 197    weekday  2025  1984  Millennials (Gen Y)
# 198    weekend  2025  1959         Baby Boomers
# 199    weekday  2025  1981  Millennials (Gen Y)
#
# [200 rows x 22 columns]

# %%
fitness_df.groupby('Generation')['steps'].mean().sort_values(ascending = False)
# Out:
# Generation
# Generation X           15687.961538
# Millennials (Gen Y)    14060.106061
# Baby Boomers           13151.783784
# Generation Z           12776.081081
# NULL                   12636.500000
# Name: steps, dtype: float64

# %%
fitness_df.to_csv('cleaned_fitness_data.csv', index = True)

# %%
df = pd.read_csv('cleaned_fitness_data.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  record_id            timestamp user_id  age  gender  \
# 0           0          1  2025-07-22 09:22:54    U026   67    Male
# 1           1          2  2025-05-28 13:53:54    U039   16  Female
# 2           2          3  2025-08-07 01:36:54    U046   62  Female
# 3           3          4  2025-07-17 01:56:54    U048   56  Female
# 4           4          5  2025-08-11 03:22:54    U042   42   Other
# 5           5          6  2025-07-25 13:00:54    U005   39  Female
# 6           6          7  2025-05-21 08:47:54    U030   61   Other
# 7           7          8  2025-06-28 14:29:54    U014   46  Female
# 8           8          9  2025-08-02 19:57:54    U036   63    Male
# 9           9         10  2025-08-31 09:54:54    U019   27   Other
#
#        activity_type  duration_min  calories_burned  heart_rate_avg  ...  \
# 0            Cycling             7              322             175  ...
# 1  Strength Training            83              265             113  ...
# 2            Cycling           118              508              98  ...
# 3           Swimming            75              270             150  ...
# 4               Yoga            76              308             141  ...
# 5               HIIT            50              471             163  ...
# 6            Walking            88              238              78  ...
# 7               Yoga            39              133             179  ...
# 8           Swimming            10              500              82  ...
# 9           Swimming           100              210             165  ...
#
#             time_stamp        date   month        day hour  season week_time  \
# 0  2025-07-22 09:22:54  2025-07-22    July    Tuesday    9  Summer   weekday
# 1  2025-05-28 13:53:54  2025-05-28     May  Wednesday   13  Spring   weekday
# 2  2025-08-07 01:36:54  2025-08-07  August   Thursday    1  Summer   weekday
# 3  2025-07-17 01:56:54  2025-07-17    July   Thursday    1  Summer   weekday
# 4  2025-08-11 03:22:54  2025-08-11  August     Monday    3  Summer   weekday
# 5  2025-07-25 13:00:54  2025-07-25    July     Friday   13  Summer   weekday
# 6  2025-05-21 08:47:54  2025-05-21     May  Wednesday    8  Spring   weekday
# 7  2025-06-28 14:29:54  2025-06-28    June   Saturday   14  Summer   weekend
# 8  2025-08-02 19:57:54  2025-08-02  August   Saturday   19  Summer   weekend
# 9  2025-08-31 09:54:54  2025-08-31  August     Sunday    9  Summer   weekend
#
#    year  born           Generation
# 0  2025  1958         Baby Boomers
# 1  2025  2009         Generation Z
# 2  2025  1963         Baby Boomers
# 3  2025  1969         Generation X
# 4  2025  1983  Millennials (Gen Y)
# 5  2025  1986  Millennials (Gen Y)
# 6  2025  1964                  NaN
# 7  2025  1979         Generation X
# 8  2025  1962         Baby Boomers
# 9  2025  1998         Generation Z
#
# [10 rows x 23 columns]

# %%
y_pos = np.arange(len(grouped['calories_burned']))
grouped = df.groupby('season')['calories_burned'].mean()
plt.bar(y_pos, grouped['calories_burned'], alpha = 0.5)
plt.xticks(y_pos, grouped['season'], rotation = 45)
plt.ylabel("Calories burnt")
plt.title("Calories lost per activity")

plt.show()
